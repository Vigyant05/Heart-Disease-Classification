# %%
import pandas as pd

data=pd.read_csv('/Users/vigyantnayak/heart_disease_classification/Dataset/myocardial/combined_dataset.csv')
data.isnull().sum()

# %%
data.head()

# %%
from ucimlrepo import fetch_ucirepo

# %%
uci_data = fetch_ucirepo(id=579)

# UCI dataset split
X_uci = uci_data.data.features     # features dataframe
y_uci = uci_data.data.targets      # targets dataframe

# Combine UCI features + targets into one dataframe
uci_df = pd.concat([X_uci, y_uci], axis=1)

# %%
uci_df.isnull().sum()

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/Users/vigyantnayak/heart_disease_classification/Dataset/heart_failure/combined_heart_failure_final.csv")

# Replace 0 → F and 1 → M
df["sex"] = df["sex"].replace({0: "F", 1: "M"})

# Save updated dataset
df.to_csv("/Users/vigyantnayak/heart_disease_classification/Dataset/heart_failure/combined_heart_failure_final.csv", index=False)

print("Sex column updated (0→F, 1→M).")
